# %%
# @title Setup
from google.colab import auth
from google.cloud import bigquery
from google.colab import data_table

project = 'bigquery-gps' # Project ID inserted based on the query results selected to explore
location = 'US' # Location inserted based on the query results selected to explore
client = bigquery.Client(project=project, location=location)
data_table.enable_dataframe_formatter()
auth.authenticate_user()

# %% [markdown]
# ## Reference SQL syntax from the original job
# Use the ```jobs.query```
# [method](https://cloud.google.com/bigquery/docs/reference/rest/v2/jobs/query) to
# return the SQL syntax from the job. This can be copied from the output cell
# below to edit the query now or in the future. Alternatively, you can use
# [this link](https://console.cloud.google.com/bigquery?j=bigquery-gps:US:script_job_5d73a048c9ee4f2d62d8bedc25733d14_1)
# back to BigQuery to edit the query within the BigQuery user interface.

# %%
# Running this code will display the query used to generate your previous job

job = client.get_job('script_job_5d73a048c9ee4f2d62d8bedc25733d14_1') # Job ID inserted based on the query results selected to explore
print(job.query)
# Out:
# select * from `nih-sra-datastore.sra.metadata`
# WHERE acc not in (select acc from AMPLICON)
# AND (librarysource = "METAGENOMIC" OR librarysource = 'METATRANSCRIPTOMIC'
#        OR organism LIKE "%microbiom%" OR organism LIKE "%metagenom%"
#        OR organism LIKE '%metatran%')
#        AND (organism LIKE "%pig%" OR organism LIKE "%swine%" OR organism LIKE "%piglet%"
#        OR organism LIKE "%hog%" OR organism LIKE "%sow%" OR organism LIKE "%boar%"
#        OR organism LIKE "%Sus scrofa%" OR organism LIKE "%Sus domesticus%" OR organism LIKE "%Sus scrofa domesticus%"
#        OR organism = "9823")

# %% [markdown]
# # Result set loaded from BigQuery job as a DataFrame
# Query results are referenced from the Job ID ran from BigQuery and the query
# does not need to be re-run to explore results. The ```to_dataframe```
# [method](https://googleapis.dev/python/bigquery/latest/generated/google.cloud.bigquery.job.QueryJob.html#google.cloud.bigquery.job.QueryJob.to_dataframe)
# downloads the results to a Pandas DataFrame by using the BigQuery Storage API.
#
# To edit query syntax, you can do so from the BigQuery SQL editor or in the
# ```Optional:``` sections below.

# %%
# Running this code will read results from your previous job

job = client.get_job('script_job_5d73a048c9ee4f2d62d8bedc25733d14_1') # Job ID inserted based on the query results selected to explore
results = job.to_dataframe()
results.head()
# Out:
# Warning: Total number of columns (37) exceeds max_columns (20). Falling back to pandas display.
#            acc assay_type                                center_name consent  \
# 0  SRR19212930        WGA              CHINA AGRICULTURAL UNIVERSITY  public
# 1  SRR10216336        WGS                 SHANGQIU NORMAL UNIVERSITY  public
# 2  SRR20684237    RNA-Seq              HUNAN AGRICULTURAL UNIVERSITY  public
# 3   ERR1855539        WGS                 FREIE UNIVERSITY OF BERLIN  public
# 4  SRR24199718        WGS  ZHEJIANG ACADEMY OF AGRICULTURAL SCIENCES  public
#
#     experiment            sample_name             instrument librarylayout  \
# 0  SRX15276971                   AA_4              DNBSEQ-T7        PAIRED
# 1   SRX6935997                   IL_1    Illumina HiSeq 2000        PAIRED
# 2  SRX16706089  Porcine metagenome-A7  Illumina NovaSeq 6000        PAIRED
# 3   ERX1917439          SAMEA99904168            NextSeq 500        PAIRED
# 4  SRX19996454                    BC6    Illumina HiSeq 2000        PAIRED
#
#      libraryselection       librarysource  ...  geo_loc_name_sam  \
# 0              RANDOM         METAGENOMIC  ...     [China:Hebei]
# 1  size fractionation             GENOMIC  ...         [missing]
# 2            Oligo-dT      TRANSCRIPTOMIC  ...  [China:Changsha]
# 3              RANDOM         METAGENOMIC  ...                []
# 4              RANDOM  METATRANSCRIPTOMIC  ...  [China:Hangzhou]
#
#   ena_first_public_run ena_last_update_run sample_name_sam  \
# 0                   []                  []              []
# 1                   []                  []              []
# 2                   []                  []              []
# 3         [2017-04-30]        [2018-11-16]    [ERS1571320]
# 4                   []                  []              []
#
#      datastore_filetype   datastore_provider  \
# 0  [run.zq, fastq, sra]       [gs, ncbi, s3]
# 1  [sra, run.zq, fastq]       [s3, gs, ncbi]
# 2  [run.zq, fastq, sra]       [ncbi, gs, s3]
# 3  [run.zq, fastq, sra]  [gs, ncbi, ena, s3]
# 4  [fastq, run.zq, sra]       [gs, ncbi, s3]
#
#                           datastore_region  \
# 0       [gs.US, ncbi.public, s3.us-east-1]
# 1       [gs.US, ncbi.public, s3.us-east-1]
# 2       [s3.us-east-1, ncbi.public, gs.US]
# 3  [ena, gs.US, ncbi.public, s3.us-east-1]
# 4       [gs.US, ncbi.public, s3.us-east-1]
#
#                                           attributes run_file_version  \
# 0  [{'k': 'bases', 'v': '6018290700'}, {'k': 'byt...                1
# 1  [{'k': 'sex_calc', 'v': 'female'}, {'k': 'base...                1
# 2  [{'k': 'bases', 'v': '6845568300'}, {'k': 'byt...                1
# 3  [{'k': 'bases', 'v': '4729759108'}, {'k': 'byt...                1
# 4  [{'k': 'bases', 'v': '6866289600'}, {'k': 'byt...                1
#
#                                                jattr
# 0  {"bases": 6018290700, "bytes": 3697199143, "ru...
# 1  {"sex_calc": "female", "bases": 41526597, "byt...
# 2  {"bases": 6845568300, "bytes": 2165644722, "ru...
# 3  {"bases": 4729759108, "bytes": 2008071098, "ru...
# 4  {"bases": 6866289600, "bytes": 2435789278, "ru...
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Show descriptive statistics using describe()
# Use the ```pandas DataFrame.describe()```
# [method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)
# to generate descriptive statistics. Descriptive statistics include those that
# summarize the central tendency, dispersion and shape of a dataset’s
# distribution, excluding ```NaN``` values. You may also use other Python methods
# to interact with your data.

# %%
results.describe()
# Out:
#             mbytes  avgspotlen       mbases  insertsize  run_file_version
# count       8959.0      8949.0       8949.0         0.0            8950.0
# mean     1493.5024  370.210191  3996.590569        <NA>          1.039553
# std    3178.428258  345.556305  6267.953149        <NA>          0.200011
# min            0.0        21.0          0.0        <NA>               1.0
# 25%          121.0       300.0        292.0        <NA>               1.0
# 50%          405.0       302.0       1285.0        <NA>               1.0
# 75%         2040.0       302.0       5449.0        <NA>               1.0
# max       106078.0      6685.0     125403.0        <NA>               3.0

# %%
 results.to_parquet('20230802-pig-microbiome-metadata.parquet')

# %%
# %ls
# Out:
# 20230802-pig-microbiome-metadata.parquet  sample_data/

# %%
results.shape
# Out:
# (8959, 37)

# %%
results['acc'].to_csv('20230802-pig-microbiome-acc.csv')

# %%
results.columns
# Out:
# Index(['acc', 'assay_type', 'center_name', 'consent', 'experiment',
#        'sample_name', 'instrument', 'librarylayout', 'libraryselection',
#        'librarysource', 'platform', 'sample_acc', 'biosample', 'organism',
#        'sra_study', 'releasedate', 'bioproject', 'mbytes', 'loaddate',
#        'avgspotlen', 'mbases', 'insertsize', 'library_name',
#        'biosamplemodel_sam', 'collection_date_sam',
#        'geo_loc_name_country_calc', 'geo_loc_name_country_continent_calc',
#        'geo_loc_name_sam', 'ena_first_public_run', 'ena_last_update_run',
#        'sample_name_sam', 'datastore_filetype', 'datastore_provider',
#        'datastore_region', 'attributes', 'run_file_version', 'jattr'],
#       dtype='object')

# %%
results[['acc', 'organism']].head()
# Out:
#            acc            organism
# 0  SRR19212930  pig gut metagenome
# 1  SRR10216336  pig gut metagenome
# 2  SRR20684237  pig gut metagenome
# 3   ERR1855539          Sus scrofa
# 4  SRR24199718      pig metagenome

# %%
results[['acc', 'organism']].to_csv('20230802-pig-microbiome.acc-org.csv', index=False)

# %%
results['organism'].value_counts()
# Out:
# pig gut metagenome             7182
# pig metagenome                 1191
# Sus scrofa                      352
# Sus scrofa domesticus           136
# African swine fever virus        89
# Trichoglossus moluccanus          4
# Dolosigranulum pigrum             2
# Ptychographa xylographoides       1
# Trichoglossum hirsutum            1
# Desulfovibrio piger               1
# Name: organism, dtype: int64

# %%
non_pig = ['African swine fever virus', 'Trichoglossus moluccanus',
           'Dolosigranulum pigrum', 'Ptychographa xylographoides',
           'Trichoglossum hirsutum', 'Desulfovibrio piger']

results = results[~results['organism'].isin(non_pig)]

# %%
results.shape
# Out:
# (8861, 37)

# %%
results['organism'].value_counts()
# Out:
# pig gut metagenome       7182
# pig metagenome           1191
# Sus scrofa                352
# Sus scrofa domesticus     136
# Name: organism, dtype: int64

# %%
results[['acc', 'organism']].to_csv('20230802-pig-microbiome.acc-org.csv', index=False)

# %%
results.to_parquet('20230802-pig-microbiome.metadata.parquet', index=False)

# %%
results['instrument'].value_counts()
# Out:
# Illumina NovaSeq 6000    4787
# Illumina MiSeq            875
# Illumina HiSeq 2000       768
# Illumina HiSeq 4000       685
# Illumina HiSeq 2500       565
# NextSeq 500               361
# MinION                    216
# Illumina HiSeq 3000       162
# 454 GS FLX Titanium       136
# GridION                    92
# HiSeq X Ten                45
# BGISEQ-500                 44
# Ion Torrent Proton         29
# Ion Torrent S5 XL          27
# DNBSEQ-T7                  18
# Ion S5 XL                  16
# NextSeq 550                13
# MGISEQ-2000RS              12
# 454 GS FLX                  9
# PacBio RS II                1
# Name: instrument, dtype: int64

# %%
results['platform'].value_counts()
# Out:
# ILLUMINA           8261
# OXFORD_NANOPORE     308
# LS454               145
# BGISEQ               74
# ION_TORRENT          72
# PACBIO_SMRT           1
# Name: platform, dtype: int64

# %%
results.groupby(['instrument', 'librarylayout', 'libraryselection', 'librarysource', 'platform']).describe()
# Out:
#                                                                                   mbytes  \
#                                                                                    count
# instrument          librarylayout libraryselection librarysource      platform
# 454 GS FLX          SINGLE        RANDOM PCR       METAGENOMIC        LS454          9.0
# 454 GS FLX Titanium SINGLE        RANDOM           METAGENOMIC        LS454         83.0
#                                   other            OTHER              LS454          3.0
#                                   unspecified      METAGENOMIC        LS454         50.0
# BGISEQ-500          SINGLE        RANDOM PCR       TRANSCRIPTOMIC     BGISEQ        44.0
# ...                                                                                  ...
# NextSeq 500         SINGLE        RANDOM           METAGENOMIC        ILLUMINA      96.0
#                                   cDNA             METATRANSCRIPTOMIC ILLUMINA       5.0
# NextSeq 550         PAIRED        RANDOM           METAGENOMIC        ILLUMINA       9.0
#                                   RANDOM PCR       METAGENOMIC        ILLUMINA       4.0
# PacBio RS II        SINGLE        other            METAGENOMIC        PACBIO_SMRT    1.0
#
#                                                                                                 \
#                                                                                           mean
# instrument          librarylayout libraryselection librarysource      platform
# 454 GS FLX          SINGLE        RANDOM PCR       METAGENOMIC        LS454          45.333333
# 454 GS FLX Titanium SINGLE        RANDOM           METAGENOMIC        LS454         122.457831
#                                   other            OTHER              LS454               12.0
#                                   unspecified      METAGENOMIC        LS454               6.72
# BGISEQ-500          SINGLE        RANDOM PCR       TRANSCRIPTOMIC     BGISEQ         11.204545
# ...                                                                                        ...
# NextSeq 500         SINGLE        RANDOM           METAGENOMIC        ILLUMINA      445.677083
#                                   cDNA             METATRANSCRIPTOMIC ILLUMINA           920.6
# NextSeq 550         PAIRED        RANDOM           METAGENOMIC        ILLUMINA     3715.555556
#                                   RANDOM PCR       METAGENOMIC        ILLUMINA          6245.5
# PacBio RS II        SINGLE        other            METAGENOMIC        PACBIO_SMRT       2808.0
#
#                                                                                                 \
#                                                                                            std
# instrument          librarylayout libraryselection librarysource      platform
# 454 GS FLX          SINGLE        RANDOM PCR       METAGENOMIC        LS454               72.0
# 454 GS FLX Titanium SINGLE        RANDOM           METAGENOMIC        LS454          175.13718
#                                   other            OTHER              LS454           9.539392
#                                   unspecified      METAGENOMIC        LS454           4.878273
# BGISEQ-500          SINGLE        RANDOM PCR       TRANSCRIPTOMIC     BGISEQ          1.487616
# ...                                                                                        ...
# NextSeq 500         SINGLE        RANDOM           METAGENOMIC        ILLUMINA      215.974145
#                                   cDNA             METATRANSCRIPTOMIC ILLUMINA      272.499174
# NextSeq 550         PAIRED        RANDOM           METAGENOMIC        ILLUMINA     2073.963724
#                                   RANDOM PCR       METAGENOMIC        ILLUMINA      284.047531
# PacBio RS II        SINGLE        other            METAGENOMIC        PACBIO_SMRT         <NA>
#
#                                                                                            \
#                                                                                       min
# instrument          librarylayout libraryselection librarysource      platform
# 454 GS FLX          SINGLE        RANDOM PCR       METAGENOMIC        LS454           0.0
# 454 GS FLX Titanium SINGLE        RANDOM           METAGENOMIC        LS454          15.0
#                                   other            OTHER              LS454           2.0
#                                   unspecified      METAGENOMIC        LS454           1.0
# BGISEQ-500          SINGLE        RANDOM PCR       TRANSCRIPTOMIC     BGISEQ          8.0
# ...                                                                                   ...
# NextSeq 500         SINGLE        RANDOM           METAGENOMIC        ILLUMINA       62.0
#                                   cDNA             METATRANSCRIPTOMIC ILLUMINA      492.0
# NextSeq 550         PAIRED        RANDOM           METAGENOMIC        ILLUMINA      881.0
#                                   RANDOM PCR       METAGENOMIC        ILLUMINA     5974.0
# PacBio RS II        SINGLE        other            METAGENOMIC        PACBIO_SMRT  2808.0
#
#                                                                                             \
#                                                                                        25%
# instrument          librarylayout libraryselection librarysource      platform
# 454 GS FLX          SINGLE        RANDOM PCR       METAGENOMIC        LS454           19.0
# 454 GS FLX Titanium SINGLE        RANDOM           METAGENOMIC        LS454           56.5
#                                   other            OTHER              LS454            7.5
#                                   unspecified      METAGENOMIC        LS454            2.0
# BGISEQ-500          SINGLE        RANDOM PCR       TRANSCRIPTOMIC     BGISEQ          10.0
# ...                                                                                    ...
# NextSeq 500         SINGLE        RANDOM           METAGENOMIC        ILLUMINA       265.0
#                                   cDNA             METATRANSCRIPTOMIC ILLUMINA       883.0
# NextSeq 550         PAIRED        RANDOM           METAGENOMIC        ILLUMINA      2735.0
#                                   RANDOM PCR       METAGENOMIC        ILLUMINA     6067.75
# PacBio RS II        SINGLE        other            METAGENOMIC        PACBIO_SMRT   2808.0
#
#                                                                                            \
#                                                                                       50%
# instrument          librarylayout libraryselection librarysource      platform
# 454 GS FLX          SINGLE        RANDOM PCR       METAGENOMIC        LS454          24.0
# 454 GS FLX Titanium SINGLE        RANDOM           METAGENOMIC        LS454          71.0
#                                   other            OTHER              LS454          13.0
#                                   unspecified      METAGENOMIC        LS454           7.0
# BGISEQ-500          SINGLE        RANDOM PCR       TRANSCRIPTOMIC     BGISEQ         10.5
# ...                                                                                   ...
# NextSeq 500         SINGLE        RANDOM           METAGENOMIC        ILLUMINA      328.5
#                                   cDNA             METATRANSCRIPTOMIC ILLUMINA      988.0
# NextSeq 550         PAIRED        RANDOM           METAGENOMIC        ILLUMINA     3064.0
#                                   RANDOM PCR       METAGENOMIC        ILLUMINA     6190.5
# PacBio RS II        SINGLE        other            METAGENOMIC        PACBIO_SMRT  2808.0
#
#                                                                                             \
#                                                                                        75%
# instrument          librarylayout libraryselection librarysource      platform
# 454 GS FLX          SINGLE        RANDOM PCR       METAGENOMIC        LS454           33.0
# 454 GS FLX Titanium SINGLE        RANDOM           METAGENOMIC        LS454           89.0
#                                   other            OTHER              LS454           17.0
#                                   unspecified      METAGENOMIC        LS454          10.75
# BGISEQ-500          SINGLE        RANDOM PCR       TRANSCRIPTOMIC     BGISEQ          13.0
# ...                                                                                    ...
# NextSeq 500         SINGLE        RANDOM           METAGENOMIC        ILLUMINA      666.75
#                                   cDNA             METATRANSCRIPTOMIC ILLUMINA      1002.0
# NextSeq 550         PAIRED        RANDOM           METAGENOMIC        ILLUMINA      4955.0
#                                   RANDOM PCR       METAGENOMIC        ILLUMINA     6368.25
# PacBio RS II        SINGLE        other            METAGENOMIC        PACBIO_SMRT   2808.0
#
#                                                                                            \
#                                                                                       max
# instrument          librarylayout libraryselection librarysource      platform
# 454 GS FLX          SINGLE        RANDOM PCR       METAGENOMIC        LS454         235.0
# 454 GS FLX Titanium SINGLE        RANDOM           METAGENOMIC        LS454         894.0
#                                   other            OTHER              LS454          21.0
#                                   unspecified      METAGENOMIC        LS454          18.0
# BGISEQ-500          SINGLE        RANDOM PCR       TRANSCRIPTOMIC     BGISEQ         14.0
# ...                                                                                   ...
# NextSeq 500         SINGLE        RANDOM           METAGENOMIC        ILLUMINA      892.0
#                                   cDNA             METATRANSCRIPTOMIC ILLUMINA     1238.0
# NextSeq 550         PAIRED        RANDOM           METAGENOMIC        ILLUMINA     7154.0
#                                   RANDOM PCR       METAGENOMIC        ILLUMINA     6627.0
# PacBio RS II        SINGLE        other            METAGENOMIC        PACBIO_SMRT  2808.0
#
#                                                                                   avgspotlen  \
#                                                                                        count
# instrument          librarylayout libraryselection librarysource      platform
# 454 GS FLX          SINGLE        RANDOM PCR       METAGENOMIC        LS454              9.0
# 454 GS FLX Titanium SINGLE        RANDOM           METAGENOMIC        LS454             83.0
#                                   other            OTHER              LS454              3.0
#                                   unspecified      METAGENOMIC        LS454             50.0
# BGISEQ-500          SINGLE        RANDOM PCR       TRANSCRIPTOMIC     BGISEQ            44.0
# ...                                                                                      ...
# NextSeq 500         SINGLE        RANDOM           METAGENOMIC        ILLUMINA          96.0
#                                   cDNA             METATRANSCRIPTOMIC ILLUMINA           5.0
# NextSeq 550         PAIRED        RANDOM           METAGENOMIC        ILLUMINA           9.0
#                                   RANDOM PCR       METAGENOMIC        ILLUMINA           4.0
# PacBio RS II        SINGLE        other            METAGENOMIC        PACBIO_SMRT        1.0
#
#                                                                                                \
#                                                                                          mean
# instrument          librarylayout libraryselection librarysource      platform
# 454 GS FLX          SINGLE        RANDOM PCR       METAGENOMIC        LS454             291.0
# 454 GS FLX Titanium SINGLE        RANDOM           METAGENOMIC        LS454        614.807229
#                                   other            OTHER              LS454        435.666667
#                                   unspecified      METAGENOMIC        LS454            313.56
# BGISEQ-500          SINGLE        RANDOM PCR       TRANSCRIPTOMIC     BGISEQ       447.795455
# ...                                                                                       ...
# NextSeq 500         SINGLE        RANDOM           METAGENOMIC        ILLUMINA     134.385417
#                                   cDNA             METATRANSCRIPTOMIC ILLUMINA           67.0
# NextSeq 550         PAIRED        RANDOM           METAGENOMIC        ILLUMINA          292.0
#                                   RANDOM PCR       METAGENOMIC        ILLUMINA         296.75
# PacBio RS II        SINGLE        other            METAGENOMIC        PACBIO_SMRT      2155.0
#
#                                                                                    ...  \
#                                                                                    ...
# instrument          librarylayout libraryselection librarysource      platform     ...
# 454 GS FLX          SINGLE        RANDOM PCR       METAGENOMIC        LS454        ...
# 454 GS FLX Titanium SINGLE        RANDOM           METAGENOMIC        LS454        ...
#                                   other            OTHER              LS454        ...
#                                   unspecified      METAGENOMIC        LS454        ...
# BGISEQ-500          SINGLE        RANDOM PCR       TRANSCRIPTOMIC     BGISEQ       ...
# ...                                                                                ...
# NextSeq 500         SINGLE        RANDOM           METAGENOMIC        ILLUMINA     ...
#                                   cDNA             METATRANSCRIPTOMIC ILLUMINA     ...
# NextSeq 550         PAIRED        RANDOM           METAGENOMIC        ILLUMINA     ...
#                                   RANDOM PCR       METAGENOMIC        ILLUMINA     ...
# PacBio RS II        SINGLE        other            METAGENOMIC        PACBIO_SMRT  ...
#
#                                                                                   insertsize  \
#                                                                                          75%
# instrument          librarylayout libraryselection librarysource      platform
# 454 GS FLX          SINGLE        RANDOM PCR       METAGENOMIC        LS454             <NA>
# 454 GS FLX Titanium SINGLE        RANDOM           METAGENOMIC        LS454             <NA>
#                                   other            OTHER              LS454             <NA>
#                                   unspecified      METAGENOMIC        LS454             <NA>
# BGISEQ-500          SINGLE        RANDOM PCR       TRANSCRIPTOMIC     BGISEQ            <NA>
# ...                                                                                      ...
# NextSeq 500         SINGLE        RANDOM           METAGENOMIC        ILLUMINA          <NA>
#                                   cDNA             METATRANSCRIPTOMIC ILLUMINA          <NA>
# NextSeq 550         PAIRED        RANDOM           METAGENOMIC        ILLUMINA          <NA>
#                                   RANDOM PCR       METAGENOMIC        ILLUMINA          <NA>
# PacBio RS II        SINGLE        other            METAGENOMIC        PACBIO_SMRT       <NA>
#
#                                                                                          \
#                                                                                     max
# instrument          librarylayout libraryselection librarysource      platform
# 454 GS FLX          SINGLE        RANDOM PCR       METAGENOMIC        LS454        <NA>
# 454 GS FLX Titanium SINGLE        RANDOM           METAGENOMIC        LS454        <NA>
#                                   other            OTHER              LS454        <NA>
#                                   unspecified      METAGENOMIC        LS454        <NA>
# BGISEQ-500          SINGLE        RANDOM PCR       TRANSCRIPTOMIC     BGISEQ       <NA>
# ...                                                                                 ...
# NextSeq 500         SINGLE        RANDOM           METAGENOMIC        ILLUMINA     <NA>
#                                   cDNA             METATRANSCRIPTOMIC ILLUMINA     <NA>
# NextSeq 550         PAIRED        RANDOM           METAGENOMIC        ILLUMINA     <NA>
#                                   RANDOM PCR       METAGENOMIC        ILLUMINA     <NA>
# PacBio RS II        SINGLE        other            METAGENOMIC        PACBIO_SMRT  <NA>
#
#                                                                                   run_file_version  \
#                                                                                              count
# instrument          librarylayout libraryselection librarysource      platform
# 454 GS FLX          SINGLE        RANDOM PCR       METAGENOMIC        LS454                    9.0
# 454 GS FLX Titanium SINGLE        RANDOM           METAGENOMIC        LS454                   83.0
#                                   other            OTHER              LS454                    3.0
#                                   unspecified      METAGENOMIC        LS454                   50.0
# BGISEQ-500          SINGLE        RANDOM PCR       TRANSCRIPTOMIC     BGISEQ                  44.0
# ...                                                                                            ...
# NextSeq 500         SINGLE        RANDOM           METAGENOMIC        ILLUMINA                96.0
#                                   cDNA             METATRANSCRIPTOMIC ILLUMINA                 5.0
# NextSeq 550         PAIRED        RANDOM           METAGENOMIC        ILLUMINA                 9.0
#                                   RANDOM PCR       METAGENOMIC        ILLUMINA                 4.0
# PacBio RS II        SINGLE        other            METAGENOMIC        PACBIO_SMRT              1.0
#
#                                                                                              \
#                                                                                        mean
# instrument          librarylayout libraryselection librarysource      platform
# 454 GS FLX          SINGLE        RANDOM PCR       METAGENOMIC        LS454             1.0
# 454 GS FLX Titanium SINGLE        RANDOM           METAGENOMIC        LS454        1.204819
#                                   other            OTHER              LS454             1.0
#                                   unspecified      METAGENOMIC        LS454             1.0
# BGISEQ-500          SINGLE        RANDOM PCR       TRANSCRIPTOMIC     BGISEQ            1.0
# ...                                                                                     ...
# NextSeq 500         SINGLE        RANDOM           METAGENOMIC        ILLUMINA          1.0
#                                   cDNA             METATRANSCRIPTOMIC ILLUMINA          1.0
# NextSeq 550         PAIRED        RANDOM           METAGENOMIC        ILLUMINA          1.0
#                                   RANDOM PCR       METAGENOMIC        ILLUMINA          1.0
# PacBio RS II        SINGLE        other            METAGENOMIC        PACBIO_SMRT       1.0
#
#                                                                                             \
#                                                                                        std
# instrument          librarylayout libraryselection librarysource      platform
# 454 GS FLX          SINGLE        RANDOM PCR       METAGENOMIC        LS454            0.0
# 454 GS FLX Titanium SINGLE        RANDOM           METAGENOMIC        LS454        0.59998
#                                   other            OTHER              LS454            0.0
#                                   unspecified      METAGENOMIC        LS454            0.0
# BGISEQ-500          SINGLE        RANDOM PCR       TRANSCRIPTOMIC     BGISEQ           0.0
# ...                                                                                    ...
# NextSeq 500         SINGLE        RANDOM           METAGENOMIC        ILLUMINA         0.0
#                                   cDNA             METATRANSCRIPTOMIC ILLUMINA         0.0
# NextSeq 550         PAIRED        RANDOM           METAGENOMIC        ILLUMINA         0.0
#                                   RANDOM PCR       METAGENOMIC        ILLUMINA         0.0
# PacBio RS II        SINGLE        other            METAGENOMIC        PACBIO_SMRT     <NA>
#
#                                                                                         \
#                                                                                    min
# instrument          librarylayout libraryselection librarysource      platform
# 454 GS FLX          SINGLE        RANDOM PCR       METAGENOMIC        LS454        1.0
# 454 GS FLX Titanium SINGLE        RANDOM           METAGENOMIC        LS454        1.0
#                                   other            OTHER              LS454        1.0
#                                   unspecified      METAGENOMIC        LS454        1.0
# BGISEQ-500          SINGLE        RANDOM PCR       TRANSCRIPTOMIC     BGISEQ       1.0
# ...                                                                                ...
# NextSeq 500         SINGLE        RANDOM           METAGENOMIC        ILLUMINA     1.0
#                                   cDNA             METATRANSCRIPTOMIC ILLUMINA     1.0
# NextSeq 550         PAIRED        RANDOM           METAGENOMIC        ILLUMINA     1.0
#                                   RANDOM PCR       METAGENOMIC        ILLUMINA     1.0
# PacBio RS II        SINGLE        other            METAGENOMIC        PACBIO_SMRT  1.0
#
#                                                                                         \
#                                                                                    25%
# instrument          librarylayout libraryselection librarysource      platform
# 454 GS FLX          SINGLE        RANDOM PCR       METAGENOMIC        LS454        1.0
# 454 GS FLX Titanium SINGLE        RANDOM           METAGENOMIC        LS454        1.0
#                                   other            OTHER              LS454        1.0
#                                   unspecified      METAGENOMIC        LS454        1.0
# BGISEQ-500          SINGLE        RANDOM PCR       TRANSCRIPTOMIC     BGISEQ       1.0
# ...                                                                                ...
# NextSeq 500         SINGLE        RANDOM           METAGENOMIC        ILLUMINA     1.0
#                                   cDNA             METATRANSCRIPTOMIC ILLUMINA     1.0
# NextSeq 550         PAIRED        RANDOM           METAGENOMIC        ILLUMINA     1.0
#                                   RANDOM PCR       METAGENOMIC        ILLUMINA     1.0
# PacBio RS II        SINGLE        other            METAGENOMIC        PACBIO_SMRT  1.0
#
#                                                                                         \
#                                                                                    50%
# instrument          librarylayout libraryselection librarysource      platform
# 454 GS FLX          SINGLE        RANDOM PCR       METAGENOMIC        LS454        1.0
# 454 GS FLX Titanium SINGLE        RANDOM           METAGENOMIC        LS454        1.0
#                                   other            OTHER              LS454        1.0
#                                   unspecified      METAGENOMIC        LS454        1.0
# BGISEQ-500          SINGLE        RANDOM PCR       TRANSCRIPTOMIC     BGISEQ       1.0
# ...                                                                                ...
# NextSeq 500         SINGLE        RANDOM           METAGENOMIC        ILLUMINA     1.0
#                                   cDNA             METATRANSCRIPTOMIC ILLUMINA     1.0
# NextSeq 550         PAIRED        RANDOM           METAGENOMIC        ILLUMINA     1.0
#                                   RANDOM PCR       METAGENOMIC        ILLUMINA     1.0
# PacBio RS II        SINGLE        other            METAGENOMIC        PACBIO_SMRT  1.0
#
#                                                                                         \
#                                                                                    75%
# instrument          librarylayout libraryselection librarysource      platform
# 454 GS FLX          SINGLE        RANDOM PCR       METAGENOMIC        LS454        1.0
# 454 GS FLX Titanium SINGLE        RANDOM           METAGENOMIC        LS454        1.0
#                                   other            OTHER              LS454        1.0
#                                   unspecified      METAGENOMIC        LS454        1.0
# BGISEQ-500          SINGLE        RANDOM PCR       TRANSCRIPTOMIC     BGISEQ       1.0
# ...                                                                                ...
# NextSeq 500         SINGLE        RANDOM           METAGENOMIC        ILLUMINA     1.0
#                                   cDNA             METATRANSCRIPTOMIC ILLUMINA     1.0
# NextSeq 550         PAIRED        RANDOM           METAGENOMIC        ILLUMINA     1.0
#                                   RANDOM PCR       METAGENOMIC        ILLUMINA     1.0
# PacBio RS II        SINGLE        other            METAGENOMIC        PACBIO_SMRT  1.0
#
#
#                                                                                    max
# instrument          librarylayout libraryselection librarysource      platform
# 454 GS FLX          SINGLE        RANDOM PCR       METAGENOMIC        LS454        1.0
# 454 GS FLX Titanium SINGLE        RANDOM           METAGENOMIC        LS454        3.0
#                                   other            OTHER              LS454        1.0
#                                   unspecified      METAGENOMIC        LS454        1.0
# BGISEQ-500          SINGLE        RANDOM PCR       TRANSCRIPTOMIC     BGISEQ       1.0
# ...                                                                                ...
# NextSeq 500         SINGLE        RANDOM           METAGENOMIC        ILLUMINA     1.0
#                                   cDNA             METATRANSCRIPTOMIC ILLUMINA     1.0
# NextSeq 550         PAIRED        RANDOM           METAGENOMIC        ILLUMINA     1.0
#                                   RANDOM PCR       METAGENOMIC        ILLUMINA     1.0
# PacBio RS II        SINGLE        other            METAGENOMIC        PACBIO_SMRT  1.0
#
# [71 rows x 40 columns]

# %%
results['jattr'][500]
# Out:
# '{"bases": 39925200, "bytes": 22978564, "run_file_create_date": "2021-01-05T11:08:00.000Z", "aliquot_sam": "aliquot 13", "collection_date_sam": ["2018-10-13"], "env_broad_scale_sam": ["pig stomach"], "env_local_scale_sam": ["stomach microbiome"], "env_medium_sam": ["chyme"], "host_sam": ["Sus scrofa domesticus"], "lat_lon_sam": ["39.91 N 116.41 E"], "replicate_sam": ["replicate 3"], "primary_search": "17213661"}'

# %%
results['jattr'][8000]
# Out:
# '{"bases": 120518, "bytes": 189684, "run_file_create_date": "2021-11-30T00:16:00.000Z", "collection_date_sam": ["2019-06"], "host_sam": ["pig"], "isolation_source_sam_ss_dpl262": ["USDA slaughterhouse"], "source_material_id_sam": ["enro at 24 hours"], "primary_search": "23498608"}'
